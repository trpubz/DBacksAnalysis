# %%
import pandas as pd

df = pd.read_csv('running_splits.csv', index_col='player_id').sort_values(by='seconds_since_hit_090')

bottomQuarter = round(df.__len__()/4)

df = df.iloc[:-bottomQuarter]
df.iloc[:, -19:]
# Out:
#            seconds_since_hit_000  seconds_since_hit_005  \
# player_id
# 682998                       0.0                   0.51
# 669352                       0.0                   0.53
# 669003                       0.0                   0.55
# 607208                       0.0                   0.56
# 608671                       0.0                   0.52
# ...                          ...                    ...
# 669134                       0.0                   0.56
# 592518                       0.0                   0.57
# 571657                       0.0                   0.57
# 571771                       0.0                   0.57
# 641598                       0.0                   0.57
#
#            seconds_since_hit_010  seconds_since_hit_015  \
# player_id
# 682998                      0.80                   1.04
# 669352                      0.83                   1.08
# 669003                      0.84                   1.08
# ...

# %%
import seaborn as sns


sns.scatterplot(df)
# Out:
# /Users/tpubz/miniconda3/envs/notebooks/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 4>()
#       1 import seaborn as sns
# ----> 4 sns.scatterplot(df, y=df.seconds_since_hit_000)
#
# File ~/miniconda3/envs/notebooks/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
# ...
