# %%
import pandas as pd

# load data
km_woba = pd.read_csv('marte_xwoba_type_22.csv')
km_woba.melt('pitch_type', value_name='obas')
# Out:
#    pitch_type variable   obas
# 0    4-Seamer    xwOBA  0.364
# 1      Slider    xwOBA  0.277
# 2    Changeup    xwOBA  0.353
# 3      Sinker    xwOBA  0.435
# 4   Curveball    xwOBA  0.244
# 5      Cutter    xwOBA  0.269
# 6    Splitter    xwOBA  0.163
# 7    4-Seamer   vs_div  0.288
# 8      Slider   vs_div  0.266
# 9    Changeup   vs_div  0.288
# 10     Sinker   vs_div  0.534
# 11  Curveball   vs_div  0.203
# 12     Cutter   vs_div  0.304
# 13   Splitter   vs_div  0.127
# 14   4-Seamer  mlb_avg  0.331
# 15     Slider  mlb_avg  0.259
# 16   Changeup  mlb_avg  0.290
# 17     Sinker  mlb_avg  0.342
# 18  Curveball  mlb_avg  0.262
# 19     Cutter  mlb_avg  0.314
# 20   Splitter  mlb_avg  0.222
# 21   4-Seamer  nl_west  0.330
# 22     Slider  nl_west  0.256
# 23   Changeup  nl_west  0.297
# 24     Sinker  nl_west  0.342
# 25  Curveball  nl_west  0.252
# 26     Cutter  nl_west  0.313
# 27   Splitter  nl_west  0.238

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [53], in <cell line: 4>()
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 4 sns.scatterplot(data=km_woba, x='pitch_type', y='obas')
#       5 plt.show()
#
# File ~/miniconda3/envs/notebooks/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...
